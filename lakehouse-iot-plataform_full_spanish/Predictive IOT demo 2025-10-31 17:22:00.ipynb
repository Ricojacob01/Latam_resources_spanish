# %%
# %pip install dbdemos

# %%
import dbdemos
dbdemos.install('lakehouse-iot-platform', catalog='latam_hunter', schema='dbdemos_iot_turbine')

# %%
import dbdemos
dbdemos.install('uc-03-data-lineage')
