-- %% [markdown]
-- ### Cuaderno de exploración de ejemplo
--
-- Usa este cuaderno para explorar los datos generados por el pipeline en tu lenguaje de programación preferido.
--
-- **Nota**: Este cuaderno no se ejecuta como parte del pipeline.

-- %%
--Explore raw historical turbine status data

SELECT * FROM json.`/Volumes/latam_hunter/dbdemos_iot_turbine/turbine_raw_landing/historical_turbine_status`

-- %%
--Explore raw sensor data
SELECT * FROM parquet.`/Volumes/latam_hunter/dbdemos_iot_turbine/turbine_raw_landing/incoming_data`

-- %%
--Explore raw turbine data

SELECT * FROM json.`/Volumes/latam_hunter/dbdemos_iot_turbine/turbine_raw_landing/turbine`
