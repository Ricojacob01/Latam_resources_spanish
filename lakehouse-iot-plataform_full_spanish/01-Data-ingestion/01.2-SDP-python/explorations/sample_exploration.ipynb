# %% [markdown]
# ### Cuaderno de exploración de ejemplo
#
# Usa este cuaderno para explorar los datos generados por el pipeline en tu lenguaje de programación preferido.
#
# **Nota**: Este cuaderno no se ejecuta como parte del pipeline.

# %%
#Explore raw historical turbine status data

sdf = spark.read.format("json").load("/Volumes/latam_hunter/dbdemos_iot_turbine/turbine_raw_landing/historical_turbine_status")
display(sdf)

# %%
#Explore raw sensor data
sdf = spark.read.format("parquet").load("/Volumes/latam_hunter/dbdemos_iot_turbine/turbine_raw_landing/incoming_data")
display(sdf)

# %%
#Explore raw turbine data

sdf = spark.read.format("json").load("/Volumes/latam_hunter/dbdemos_iot_turbine/turbine_raw_landing/turbine")
display(sdf)
