# %% [markdown]
# # 99 - Carga Incremental
#
# Simula la llegada de **nuevos datos** durante el taller.
#
# Ejecutar antes de re-correr el pipeline o como tarea en un Job.

# %%
# %run ./00_variables

# %%
carga_datos("incremental")

# %%
print("Archivos incrementales cargados:")
for folder in dbutils.fs.ls(vol_path):
    if folder.isDir():
        print(f"  {folder.name}: {len(dbutils.fs.ls(folder.path))} archivos")
