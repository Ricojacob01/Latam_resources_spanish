# %% [markdown]
# # 99 - Carga Incremental
#
# Ejecutar **Run All**. Usar antes de re-correr el pipeline o en un Job.

# %%
try:
    import git
except ImportError:
    # %pip install gitpython -q
    import git

# %%
# %run ./00_variables

# %%
carga_datos("incremental")
